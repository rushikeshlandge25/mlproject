# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("preprocessing_data.csv")

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23    4      5        1   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    3      5        2   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23    1      5        4   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    3      1        3   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31    1      0        1   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72    4      6        2   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72    1      6        2   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70    2      6        2   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    3      2        1   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    4      6        1   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z
# 0       0.23    4      5        1   61.5   55.0  3.95  3.98  2.43
# 1       0.21    3      5        2   59.8   61.0  3.89  3.84  2.31
# 2       0.23    1      5        4   56.9   65.0  4.05  4.07  2.31
# 3       0.29    3      1        3   62.4   58.0  4.20  4.23  2.63
# 4       0.31    1      0        1   63.3   58.0  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...
# 53935   0.72    4      6        2   60.8   57.0  5.75  5.76  3.50
# 53936   0.72    1      6        2   63.1   55.0  5.69  5.75  3.61
# 53937   0.70    2      6        2   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    3      2        1   61.0   58.0  6.15  6.12  3.74
# 53939   0.75    4      6        1   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  int64
#  2   color    53940 non-null  int64
#  3   clarity  53940 non-null  int64
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(4)
# memory usage: 4.1 MB

# %%
import pandas as pd
df=pd.read_csv("D:\Rushikesh Landge\datasets\diamonds.csv")
df=df.drop('id', axis=1)
X = df.drop('price', axis=1)
y = df['price']
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\R'
# <>:2: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\saai\AppData\Local\Temp\ipykernel_18144\2296295091.py:2: SyntaxWarning: invalid escape sequence '\R'
#   df=pd.read_csv("D:\Rushikesh Landge\datasets\diamonds.csv")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
numerical_column = X.select_dtypes(exclude=object).columns
categorical_column = X.select_dtypes(include='object').columns

# Sequence for the ordinal encoding for correct price pridiction purpose
cut_cat = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_cat = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_cat = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score,root_mean_squared_error,mean_squared_error,mean_absolute_error

num_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaling', StandardScaler())
])

cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoding', OrdinalEncoder(
        categories=[cut_cat, color_cat, clarity_cat],handle_unknown='error'

    ))
])

col_transform = ColumnTransformer([
    ('num_pipeline', num_pipe, numerical_column),
    ('cat_pipeline', cat_pipe, categorical_column),
    
])

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
rf=RandomForestRegressor(
    n_estimators=100,
    max_depth=5,
    n_jobs=-1,
    random_state=42,

)

Pipe3=Pipeline([
    ('preprosessdata',col_transform),
    ('model',rf)
])

# %%
# before doing the enconding the feature are 
x_train
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 19497   1.21      Ideal     H    VVS2   61.3   57.0  6.92  6.87  4.23
# 31229   0.31      Ideal     E     VS2   62.0   56.0  4.38  4.36  2.71
# 22311   1.21      Ideal     E     VS1   62.4   57.0  6.75  6.83  4.24
# 278     0.81      Ideal     F     SI2   62.6   55.0  5.92  5.96  3.72
# 6646    0.79      Ideal     I    VVS2   61.7   56.0  5.94  5.95  3.67
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 11284   1.05  Very Good     I     VS2   62.4   59.0  6.48  6.51  4.05
# 44732   0.47      Ideal     D     VS1   61.0   55.0  5.03  5.01  3.06
# 38158   0.33  Very Good     F      IF   60.3   58.0  4.49  4.46  2.70
# 860     0.90    Premium     J     SI1   62.8   59.0  6.13  6.03  3.82
# 15795   1.14    Premium     F     SI1   60.4   58.0  6.82  6.79  4.11
#
# [37758 rows x 9 columns]

# %%
#Here is the values for after appying EDA (StandardScalar(),SimpleImputer())
x_train
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 0.862659            -0.311437            -0.207099
# 1                -1.029889             0.178549            -0.656213
# 2                 0.862659             0.458541            -0.207099
# 3                 0.021527             0.598537            -1.105327
# 4                -0.020530            -0.031445            -0.656213
# ...                    ...                  ...                  ...
# 37753             0.526206             0.458541             0.691128
# 37754            -0.693436            -0.521432            -1.105327
# 37755            -0.987832            -1.011418             0.242014
# 37756             0.210782             0.738533             0.691128
# 37757             0.715461            -0.941420             0.242014
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# ...

# %%
x_train=pd.DataFrame(col_transform.fit_transform(x_train),columns=col_transform.get_feature_names_out())

# %%
col_transform.get_feature_names_out()
# Out:
# array(['num_pipeline__carat', 'num_pipeline__depth',
#        'num_pipeline__table', 'num_pipeline__x', 'num_pipeline__y',
#        'num_pipeline__z', 'cat_pipeline__cut', 'cat_pipeline__color',
#        'cat_pipeline__clarity'], dtype=object)

# %%
x_test
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 1388    0.24      Ideal     G    VVS1   62.1   56.0  3.97  4.00  2.47
# 50052   0.58  Very Good     F    VVS2   60.0   57.0  5.44  5.42  3.26
# 41645   0.40      Ideal     E    VVS2   62.1   55.0  4.76  4.74  2.95
# 42377   0.43    Premium     E    VVS2   60.8   57.0  4.92  4.89  2.98
# 17244   1.55      Ideal     E     SI2   62.3   55.0  7.44  7.37  4.61
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 29577   0.41    Premium     E     SI1   61.2   59.0  4.78  4.82  2.94
# 12564   1.06      Ideal     H     SI1   63.0   55.0  6.49  6.44  4.08
# 24786   1.51    Premium     G     VS2   60.8   60.0  7.42  7.38  4.50
# 1332    0.71       Good     F    VVS2   58.9   61.0  5.80  5.90  3.44
# 42527   0.40      Ideal     F    VVS1   60.7   56.0  4.79  4.77  2.90
#
# [16182 rows x 9 columns]

# %%
x_test=pd.DataFrame(col_transform.fit_transform(x_test),columns=col_transform.get_feature_names_out())

# %%
x_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                -1.177152             0.235906            -0.642780
# 1                -0.454302            -1.220570            -0.198865
# 2                -0.836987             0.235906            -1.086695
# 3                -0.773206            -0.665722            -0.198865
# 4                 1.607947             0.374617            -1.086695
# ...                    ...                  ...                  ...
# 16177            -0.815727            -0.388298             0.688966
# 16178             0.566192             0.860109            -1.086695
# 16179             1.522906            -0.665722             1.132881
# 16180            -0.177918            -1.983486             1.576796
# 16181            -0.836987            -0.735078            -0.642780
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# ...

# %%
Pipe3.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprosessdata',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoding',
# ...

# %%
y_pred=Pipe3.predict(x_test)

# %%
print(f" The value of random forest model r2 score is:- {r2_score(y_pred,y_test) * 100} ")
# Out:
#  The value of random forest model r2 score is:- 94.57275304394011

# %%
print(f" The value of mean_absolte_error is:- {mean_absolute_error(y_pred,y_test)}")
print(f" The value of mean_squared_error is:- {mean_squared_error(y_pred,y_test)}")
print(f" The value of root_mean_squared_error is:- {root_mean_squared_error(y_pred,y_test)}")
# Out:
#  The value of mean_absolte_error is:- 516.595308950746
#  The value of mean_squared_error is:- 793616.8725878514
#  The value of root_mean_squared_error is:- 890.8517680219596

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()

# %%
numerical_column = X.select_dtypes(exclude=object).columns
categorical_column = X.select_dtypes(include='object').columns

# Sequence for the ordinal encoding for correct price pridiction purpose
cut_cat = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_cat = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_cat = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import LinearSVR
from sklearn.linear_model import LinearRegression,Lasso,Ridge,LogisticRegression
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score,root_mean_squared_error,mean_squared_error,mean_absolute_error

num_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaling', StandardScaler())
])

cat_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoding', OrdinalEncoder(
        categories=[cut_cat, color_cat, clarity_cat],handle_unknown='error'

    ))
])

col_transform = ColumnTransformer([
    ('num_pipeline', num_pipe, numerical_column),
    ('cat_pipeline', cat_pipe, categorical_column),
    
])

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
lr=LinearRegression()
rg=Ridge()
lg=LogisticRegression()
svr=LinearSVR()


rf=RandomForestRegressor(
    n_estimators=100,
    max_depth=5,
    n_jobs=-1,
    random_state=42,

)

Pipe3=Pipeline([
    ('preprosessdata',col_transform),
    ('model',lr)
])

# %%
Pipe3
# Out:
# Pipeline(steps=[('preprosessdata',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoding',
# ...

# %%
Pipe3.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprosessdata',
#                  ColumnTransformer(transformers=[('num_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaling',
#                                                                    StandardScaler())]),
#                                                   Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                                  ('cat_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoding',
# ...

# %%
new_pred=Pipe3.predict(x_test)
print("The r2 score for the all linear to is same ",r2_score(new_pred,y_test)*100)
# Out:
# The r2 score for the all linear to is same  89.78001032166082
